# %% [markdown]
# <a href="https://colab.research.google.com/github/NARENBALAJI-J/FMU-lab/blob/main/Naren_Python_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Chapter 10 Exercises**

# %% [markdown]
# Exercise 10-1 (scores_by_score.py) Redo scores.py, printing out the students in descending order by score. TIP You will not need to change anything in scores.py other than the loop that prints out the names and scores

# %%
def get_grade(score):
    if score >= 95:
        return 'A'
    elif score >= 89:
        return 'B'
    elif score >= 83:
        return 'C'
    elif score >= 75:
        return 'D'
    else:
        return 'F'

scores = {}

file_path = "/content/Testscores.txt"
with open(file_path, 'r') as f:
    for line in f:
        parts = line.strip().split()
        if len(parts) == 2:
            name, score = parts
            scores[name] = int(score)

print("Name\tScore\tGrade")

# Sort in descending order by score
for name, score in sorted(scores.items(), key=lambda item: item[1], reverse=True):
    grade = get_grade(score)
    print(f"{name}\t{score}\t{grade}")

avg_score = sum(scores.values()) / len(scores)
print(f"\nAverage Score: {avg_score:.2f}")
# Out:
# Name	Score	Grade
# Bob	95	A
# Diana	95	A
# Hannah	91	B
# Alice	88	C
# Fiona	88	C
# Ian	85	C
# George	77	D
# Charlie	72	F
# Jenny	72	F
# Ethan	64	F
#
# Average Score: 82.70

# %% [markdown]
# Exercise 10-2 (alt_sorted.py) Read in the file alt.txt. Put all the words that start with 'a' in to a file named a_sorted.txt, in sorted order. Put all the words that start with 'b' in b_sorted.txt, in reverse sorted order. TIP Read through the file once, putting lines into two lists

# %%
with open("/content/aandb.txt", "r") as infile:
    words = infile.read().split()  # read all words (split by whitespace)

a_words = []
b_words = []

# Separate words starting with 'a' or 'b'
for word in words:
    if word.lower().startswith('a'):
        a_words.append(word)
    elif word.lower().startswith('b'):
        b_words.append(word)

# Sort the lists
a_words.sort(reverse=True)  # reverse order (Z → A)
b_words.sort(reverse=True)  # reverse order (Z → A)

# Write 'a' words
with open("a_sorted.txt", "w") as a_file:
    for word in a_words:
        a_file.write(word + "\n")

# Write 'b' words
with open("b_sorted.txt", "w") as b_file:
    for word in b_words:
        b_file.write(word + "\n")

print("Files created: a_sorted.txt and b_sorted.txt")
# Out:
# Files created: a_sorted.txt and b_sorted.txt

# %% [markdown]
# Exercise 10-3 (sort_fruit.py) Using the file fruit.txt, print it out: • sorted by name case-sensitively (the default) • sorted by name case-insensitively (ignoring case) • sorted by length of name, then by name • sorted by the 2nd letter of the name, then the first letter

# %%
with open("/content/fruitnames.txt", "r") as f:
    fruits = [line.strip() for line in f if line.strip()]  # remove empty lines

# Case-sensitive sort (default)
print("1. Sorted by name (case-sensitive):")
for fruit in sorted(fruits):
    print(fruit)

# Case-insensitive sort
print("\n2. Sorted by name (case-insensitive):")
for fruit in sorted(fruits, key=str.lower):
    print(fruit)

#Sorted by length, then by name
print("\n3. Sorted by length of name, then by name:")
for fruit in sorted(fruits, key=lambda x: (len(x), x)):
    print(fruit)

#Sorted by 2nd letter, then by 1st letter
print("\n4. Sorted by 2nd letter, then by 1st letter:")
for fruit in sorted(fruits, key=lambda x: (x[1] if len(x) > 1 else '', x[0])):
    print(fruit)
# Out:
# 1. Sorted by name (case-sensitive):
# Apricot
# Avocado
# Banana
# Fig
# Kiwi
# Orange
# Papaya
# apple
# blueberry
# cherry
# grape
# lime
# mango
# pear
# plum
#
# 2. Sorted by name (case-insensitive):
# apple
# Apricot
# Avocado
# Banana
# blueberry
# cherry
# Fig
# grape
# Kiwi
# lime
# mango
# Orange
# Papaya
# pear
# plum
#
# 3. Sorted by length of name, then by name:
# Fig
# Kiwi
# lime
# pear
# plum
# apple
# grape
# mango
# Banana
# Orange
# Papaya
# cherry
# Apricot
# Avocado
# blueberry
#
# 4. Sorted by 2nd letter, then by 1st letter:
# Banana
# Papaya
# mango
# pear
# cherry
# Fig
# Kiwi
# lime
# blueberry
# plum
# Apricot
# apple
# Orange
# grape
# Avocado

# %% [markdown]
# Exercise 10-4 (sort_presidents.py)
#
# Using the file presidents.txt, print out the presidents' first name, last name, and state of birth, sorted by last name, then first name. TIP Use the split() method on each line to get the individual field

# %%
# sort_presidents.py

# Read file and split lines
with open("/content/presidents.txt", "r") as f:
    presidents = [line.strip().split() for line in f if line.strip()]

# Sort by last name, then first name
sorted_presidents = sorted(presidents, key=lambda x: (x[1], x[0]))

# Print header
print(f"{'First Name':<15}{'Last Name':<20}{'State of Birth':<20}")
print("-" * 55)

# Print each row with alignment
for first, last, state in sorted_presidents:
    print(f"{first:<15}{last:<20}{state:<20}")
# Out:
# First Name     Last Name           State of Birth
# -------------------------------------------------------
# John           Adams               Massachusetts
# Chester        Arthur              Vermont
# Joe            Biden               Pennsylvania
# James          Buchanan            Pennsylvania
# George         Bush                Massachusetts
# Jimmy          Carter              Georgia
# Grover         Cleveland           New_Jersey
# Bill           Clinton             Arkansas
# Calvin         Coolidge            Vermont
# Dwight         Eisenhower          Texas
# Millard        Fillmore            New_York
# Gerald         Ford                Nebraska
# James          Garfield            Ohio
# Ulysses        Grant               Ohio
# Warren         Harding             Ohio
# Benjamin       Harrison            Ohio
# Rutherford     Hayes               Ohio
# William        Henry_Harrison      Virginia
# Herbert        Hoover              Iowa
# Andrew         Jackson             South_Carolina
# Thomas         Jefferson           Virginia
# Andrew         Johnson             North_Carolina
# Lyndon         Johnson             Texas
# John           Kennedy             Massachusetts
# Abraham        Lincoln             Kentucky
# James          Madison             Virginia
# William        McKinley            Ohio
# James          Monroe              Virginia
# Richard        Nixon               California
# Barack         Obama               Hawaii
# Franklin       Pierce              New_Hampshire
# James          Polk                North_Carolina
# John           Quincy_Adams        Massachusetts
# Ronald         Reagan              Illinois
# Franklin       Roosevelt           New_York
# Theodore       Roosevelt           New_York
# William        Taft                Ohio
# Zachary        Taylor              Virginia
# Harry          Truman              Missouri
# Donald         Trump               New_York
# John           Tyler               Virginia
# Martin         Van_Buren           New_York
# George         W._Bush             Connecticut
# George         Washington          Virginia
# Woodrow        Wilson              Virginia

# %% [markdown]
# **Chapter 11 Exercises**

# %% [markdown]
# Exercise 11-1 (c2f_loop_safe.py) Rewrite c2f_loop.py to handle the error that occurs if the user enters non-numeric data. The script should print a message and keep going if an error occur

# %%
while True:
    temp = input("Enter temperature in Celsius (or 'q' to quit): ")

    # Exit condition
    if temp.lower() == 'q':
        print("Exiting the converter.")
        break
    elif temp == '':
        continue

    # Try converting input safely
    try:
        celsius = float(temp)
        fahrenheit = ((9 * celsius) / 5) + 32
        print(f"{celsius} Celsius is equal to {fahrenheit:.2f} Fahrenheit.\n")
    except ValueError:
        print(" Invalid input! Please enter a numeric temperature.\n")
# Out:
# Enter temperature in Celsius (or 'q' to quit): 30
# 30.0 Celsius is equal to 86.00 Fahrenheit.
#
# Enter temperature in Celsius (or 'q' to quit): 10
# 10.0 Celsius is equal to 50.00 Fahrenheit.
#
# Enter temperature in Celsius (or 'q' to quit): q
# Exiting the converter.

# %% [markdown]
# **Chapter 12 Exercises**

# %% [markdown]
# Exercise 12-1
#
# Part A (temp_conv.py) Create a module that implements two temperature conversion functions, c2f and f2c. Conversion formulas F = ((9 * C) / 5.0 ) + 32 C = (F - 32) * (5.0/9) TIP write some simple code in the if name == "main" code to do a simple test of the functions

# %%
def c2f(celsius):
    """
    Convert Celsius to Fahrenheit
    F = ((9 * C) / 5.0) + 32
    """
    return ((9 * celsius) / 5.0) + 32

def f2c(fahrenheit):
    """
    Convert Fahrenheit to Celsius
    C = (F - 32) * (5.0 / 9)
    """
    return (fahrenheit - 32) * (5.0 / 9)

# Simple test code
if __name__ == "__main__":
    # Test Celsius to Fahrenheit
    c = 100
    f = c2f(c)
    print(f"{c} Celsius is {f:.2f} Fahrenheit")

    # Test Fahrenheit to Celsius
    f = 212
    c = f2c(f)
    print(f"{f} Fahrenheit is {c:.2f} Celsius")
# Out:
# 100 Celsius is 212.00 Fahrenheit
# 212 Fahrenheit is 100.00 Celsius

# %% [markdown]
# Part B (c2f_mod.py) Re-implement c2f.py using temp_conv

# %%
from temp_conv import c2f

while True:
    temp = input("Enter temperature in Celsius (or 'q' to quit): ")

    if temp.lower() == 'q':
        print("Exiting the converter.")
        break
    elif temp == '':
        continue

    try:
        celsius = float(temp)
        fahrenheit = c2f(celsius)  # use the module function
        print(f"{celsius} Celsius is equal to {fahrenheit:.2f} Fahrenheit.\n")
    except ValueError:
        print(" Invalid input! Please enter a numeric temperature.\n")
# Out:
# Enter temperature in Celsius (or 'q' to quit): 33
# 33.0 Celsius is equal to 91.40 Fahrenheit.
#
# Enter temperature in Celsius (or 'q' to quit): 40
# 40.0 Celsius is equal to 104.00 Fahrenheit.
#
# Enter temperature in Celsius (or 'q' to quit): q
# Exiting the converter.

# %% [markdown]
# Part C (f2c.py) Re-implement c2f.py as f2c.py (take Fahrenheit on command line) using temp_conv

# %%
# f2c_colab.py
from temp_conv import f2c  # import conversion function
from datetime import datetime

# Ask user for input
temp_str = input("Enter temperature in Fahrenheit: ")

try:
    fahrenheit = float(temp_str)
    celsius = f2c(fahrenheit)
    print(f"{fahrenheit} Fahrenheit is equal to {celsius:.2f} Celsius")
except ValueError:
    # Log error to file
    log_message = f"[{datetime.now()}] ERROR: Invalid input '{temp_str}' - not a valid number.\n"
    with open("f2c.log", "a") as log_file:
        log_file.write(log_message)
    print("Invalid input! Error logged to f2c.log.")
# Out:
# Enter temperature in Fahrenheit: 100
# 100.0 Fahrenheit is equal to 37.78 Celsius

# %% [markdown]
# Part D (c2f_loop_mod.py)
# Re-implement c2f_loop.py using temp_conv.

# %%
# c2f_loop_mod.py
from temp_conv import c2f  # import Celsius→Fahrenheit function

while True:
    temp = input("Enter temperature in Celsius (or 'q' to quit): ")

    # Exit the loop
    if temp.lower() == 'q':
        print("Exiting the converter.")
        break
    elif temp == '':
        continue

    # Try converting safely
    try:
        celsius = float(temp)
        fahrenheit = c2f(celsius)  # use module function
        print(f"{celsius} Celsius is equal to {fahrenheit:.2f} Fahrenheit.\n")
    except ValueError:
        print("Invalid input! Please enter a numeric temperature.\n")
# Out:
# Enter temperature in Celsius (or 'q' to quit): 28
# 28.0 Celsius is equal to 82.40 Fahrenheit.
#
# Enter temperature in Celsius (or 'q' to quit): 25
# 25.0 Celsius is equal to 77.00 Fahrenheit.
#
# Enter temperature in Celsius (or 'q' to quit): q
# Exiting the converter.

# %% [markdown]
# **Chapter 13 Exercises**

# %% [markdown]
# Exercise 13-1 (pyfind.py) Write a script which takes two or more arguments. The first argument is the pattern to search for; the remaining arguments are files to search. For each file, print out all lines which match the pattern. [1] Example python pyfind.py freezer DATA/words.txt DATA/parrot.t

# %%
pattern = input("Enter the pattern to search for: ")

file_input = input("Enter file names separated by spaces: ")
file_list = file_input.split()  # split into a list of file names

for filename in file_list:
    try:
        with open(filename, 'r') as f:
            for line_num, line in enumerate(f, start=1):
                if pattern in line:
                    print(f"{filename}:{line_num}: {line.strip()}")
    except FileNotFoundError:
        print(f"File not found: {filename}")
    except Exception as e:
        print(f"Error reading {filename}: {e}")
# Out:
# Enter the pattern to search for: freezer
# Enter file names separated by spaces: wordd.txt parrot.txt
# wordd.txt:2: freezer
# wordd.txt:8: deepfreezer
# wordd.txt:11: freezerburn
# parrot.txt:7: It is an ex-bird, gone to the freezer!

# %% [markdown]
# Exercise 13-2 (mark_big_words.py) Copy parrot.txt to bigwords.txt adding asterisks around all words that are 8 or more characters long. HINT: Use the \b anchor to indicate beginning or end of a word

# %%
import re

input_file = "parrot.txt"
output_file = "bigwords.txt"

pattern = r'\b(\w{8,})\b'

with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
    for line in infile:
        new_line = re.sub(pattern, r'*\1*', line)
        outfile.write(new_line)

print(f"Processed file saved as {output_file}")
# Out:
# Processed file saved as bigwords.txt

# %% [markdown]
# Exercise 13-3 (print_numbers.py) Write a script to print out all lines in custinfo.dat which contain phone numbers. A phone number consists of three digits, a dash, and four more digits.

# %%
import re

input_file = "/content/custinfo.txt"
phone_pattern = r'\b\d{3}-\d{3}-\d{4}\b'

with open(input_file, 'r') as f:
    for line_num, line in enumerate(f, start=1):
        if re.search(phone_pattern, line):
            print(f"{line_num}: {line.strip()}")
# Out:
# 1: John Doe, 123 Main St, Springfield, 555-123-4567
# 3: Customer Service: 800-432-1987
# 5: Mark Wilson, 42 Pine Rd, Lakeside, 444-987-6543

# %% [markdown]
# Exercise 13-4 (word_freq.py) Write a script that will read a text file and print out a list of all the words in the file, normalized to lower case, and with the number of times that word occurred in the file. Use the regular expression [^\w']+ for splitting each line into words. Test with any of the text files in the DATA folder. HINT: Use a dictionary for counting. NOTE The specified pattern matches one or more characters that are neither letters, digits, underscores, nor apostrophes

# %%
import re

filename = input("Enter filename: ")

word_counts = {}

split_pattern = r"[^\w']+"

try:
    with open(filename, 'r') as f:
        for line in f:
            words = re.split(split_pattern, line.strip().lower())
            for word in words:
                if word:
                    word_counts[word] = word_counts.get(word, 0) + 1

    print("\nWord Frequency List:\n")
    for word in sorted(word_counts):
        print(f"{word:<15} {word_counts[word]}")

except FileNotFoundError:
    print("Error: File not found. Please check the filename and path.")
# Out:
# Enter filename: word_freq.txt
#
# Word Frequency List:
#
# a               7
# and             1
# are             1
# beautiful       5
# birds           1
# but             1
# day             5
# don't           1
# enjoying        1
# everyone        1
# forever         1
# is              2
# isn't           1
# it              1
# it's            3
# last            1
# little          1
# memories        1
# moments         1
# notice          1
# of              1
# really          1
# shining         1
# singing         1
# smile           1
# song            1
# stay            1
# sun             1
# sunny           1
# the             4
# things          1
# truly           1
# we              1
# when            1
# will            1
# world           1
# yes             1

# %% [markdown]
# **Chapter 14 Exercises**

# %% [markdown]
# Exercise 14-1 (knight.py, knight_info.py)
# Part 1:
# Create a module which defines a class named Knight.
# The initializer for the class should expect the knight’s name as a parameter. Get the data from
# knights.txt to initialize the object.
# The object should have the following read-only properties:
# name
# title
# favorite_color
# quest
# comment
# Example
# from knight import Knight
# k = Knight("Arthur")
# print k.favorite_color

# %%
import os

# ----- Define the Knight class -----
class Knight:
    def __init__(self, name, data_file="/content/Knights.txt"):
        self._name = name
        self._title = None
        self._favorite_color = None
        self._quest = None
        self._comment = None

        # Check if the data file exists
        if not os.path.exists(data_file):
            raise FileNotFoundError(f"{data_file} not found.")

        # Read the knight data from file
        with open(data_file, "r") as f:
            for line in f:
                parts = [p.strip() for p in line.strip().split(",")]
                if len(parts) != 5:
                    continue  # skip invalid lines
                n, t, color, quest, comment = parts
                if n.lower() == name.lower():
                    self._title = t
                    self._favorite_color = color
                    self._quest = quest
                    self._comment = comment
                    break

        # If knight not found
        if self._title is None:
            raise ValueError(f"No knight found with name '{name}'")

    # Read-only properties
    @property
    def name(self):
        return self._name

    @property
    def title(self):
        return self._title

    @property
    def favorite_color(self):
        return self._favorite_color

    @property
    def quest(self):
        return self._quest

    @property
    def comment(self):
        return self._comment

if __name__ == "__main__":
    try:
        k = Knight("Arthur")
        print("Name:", k.name)
        print("Title:", k.title)
        print("Favorite Color:", k.favorite_color)
        print("Quest:", k.quest)
        print("Comment:", k.comment)
    except Exception as e:
        print(e)
# Out:
# Name: Arthur
# Title: King
# Favorite Color: Blue
# Quest: Holy Grail
# Comment: Noble and brave

# %% [markdown]
# Part 2: Create an application to use the Knight class created in part one. For each knight specified on the command line, create a knight object and print out the knight’s name, favorite color, quest, and comment. Precede the name with the knight’s title. Example knight_info.py Arthur Bedevere Name: King Arthur Favorite Color: blue Quest: The Grail Comment: King of the Britons Name: Sir Bedevere Favorite Color: red, no, blue! Quest: The Grail Comment: AARRRRRRRGGGGHH

# %%
import os

# ----- Define the Knight class -----
class Knight:
    def __init__(self, name, data_file="/content/Knights.txt"):
        self._name = name
        self._title = None
        self._favorite_color = None
        self._quest = None
        self._comment = None

        # Check if the data file exists
        if not os.path.exists(data_file):
            raise FileNotFoundError(f"{data_file} not found.")

        # Read the knight data from file
        with open(data_file, "r") as f:
            for line in f:
                parts = [p.strip() for p in line.strip().split(",")]
                if len(parts) != 5:
                    continue  # skip invalid lines
                n, t, color, quest, comment = parts
                if n.lower() == name.lower():
                    self._title = t
                    self._favorite_color = color
                    self._quest = quest
                    self._comment = comment
                    break

        # If knight not found
        if self._title is None:
            raise ValueError(f"No knight found with name '{name}'")

    # Read-only properties
    @property
    def name(self):
        return self._name

    @property
    def title(self):
        return self._title

    @property
    def favorite_color(self):
        return self._favorite_color

    @property
    def quest(self):
        return self._quest

    @property
    def comment(self):
        return self._comment


# ----- Application code -----
if __name__ == "__main__":
    print("Enter knight names separated by commas (e.g., Arthur,Lancelot,Gawain):")
    input_names = input().split(",")

    for name in input_names:
        name = name.strip()  # remove extra spaces
        try:
            k = Knight(name)
            print(f"\n{ k.title } { k.name }")
            print(f"Name: {k.title} {k.name}")
            print(f"Favorite Color: {k.favorite_color}")
            print(f"Quest: {k.quest}")
            print(f"Comment: {k.comment}")
        except Exception as e:
            print(f"Error for '{name}': {e}")
# Out:
# Enter knight names separated by commas (e.g., Arthur,Lancelot,Gawain):
# Arthur,Lancelot
#
# King Arthur
# Name: King Arthur
# Favorite Color: Blue
# Quest: Holy Grail
# Comment: Noble and brave
#
# Sir Lancelot
# Name: Sir Lancelot
# Favorite Color: Green
# Quest: Rescue the Queen
# Comment: Fearless and loyal

# %% [markdown]
# **Chapter 15 Exercises**

# %% [markdown]
# Exercise 15-1 (print_sys_info.py) Use the module os to print out the pathname separator, the PATH variable separator, and the extension separator for your OS.

# %%
import os

print("System Information:")

print("Pathname separator:", os.sep)

print("PATH variable separator:", os.pathsep)

print("Extension separator:", os.extsep)
# Out:
# System Information:
# Pathname separator: /
# PATH variable separator: :
# Extension separator: .

# %% [markdown]
# Exercise 15-2 (file_size.py) Write a script that accepts one or more files on the command line, and prints out the size, one file per line. If any argument is not a file, print out an error message. TIP You will need the os.path module
#
#
# [ ]

# %%
import os

# Ask user for file names (space-separated)
file_input = input("Enter file names separated by spaces: ")
file_list = file_input.split()

for filename in file_list:
    if os.path.isfile(filename):
        size_bytes = os.path.getsize(filename)
        print(f"{filename}: {size_bytes} bytes")
    else:
        print(f" Error: '{filename}' is not a valid file.")
# Out:
# Enter file names separated by spaces: wordd.txt parrot.txt
# wordd.txt: 96 bytes
# parrot.txt: 328 bytes

# %% [markdown]
# **Chapter 16 Exercises**

# %% [markdown]
# Exercise 16-1 Create a virtual environment named spam and activate it. Install the roman module. Create a requirements.txt file. Deactivate spam. Create another virtual environment named ham and activate it. Using requirements.txt, make the ham environment the same as spam

# %%
# !pip install roman

import roman
print(roman.toRoman(2025))  # Example usage


# !pip freeze > minimal_requirements.txt

# !pip install -r minimal_requirements.txt
# Out:
# Collecting roman
#   Downloading roman-5.1-py3-none-any.whl.metadata (4.2 kB)
# Downloading roman-5.1-py3-none-any.whl (5.8 kB)
# Installing collected packages: roman
# Successfully installed roman-5.1
# MMXXV
# Collecting cudf-cu12@ https://pypi.nvidia.com/cudf-cu12/cudf_cu12-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (from -r minimal_requirements.txt (line 74))
#   Downloading https://pypi.nvidia.com/cudf-cu12/cudf_cu12-25.6.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 27.3 MB/s eta 0:00:00
# Collecting en_core_web_sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl#sha256=1932429db727d4bff3deed6b34cfc05df17794f4a52eeb26cf8928f7c1a0fb85 (from -r minimal_requirements.txt (line 113))
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 105.6 MB/s eta 0:00:00
# Processing /colabtools/dist/google_colab-1.0.0.tar.gz (from -r minimal_requirements.txt (line 184))
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/colabtools/dist/google_colab-1.0.0.tar.gz'
